# %%
from encode_api import encode
import importlib


import encode_api.encode
importlib.reload(encode_api.encode)
# Out:
# <module 'encode_api.encode' from '/n/data1/hms/dbmi/park/sandra/ctDNA_loci/fragment_git/encode_api/encode.py'>

# %%
# if you know exact tissue ontology available in ENCODE:
c = encode.FeatureConfig('prostate gland',  True, False, "H3K4me3", "CTCF", "transcription")
results = c.parse_url(rfa='ENCODE4') # you can change it to ENCODE3, to restrict files processed from one of ENCODE3 or ENCODE4
results
# Out:
# https://www.encodeproject.org/search/?type=Experiment&status=released&assay_title=Histone+ChIP-seq&biosample_ontology.classification=tissue&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens&replicates.library.biosample.perturbed=false&biosample_ontology.term_name=prostate+gland&award.project=ENCODE&target.label=H3K4me3&frame=embedded&format=json
#         organ_slims           system_slims       term_name cell_slims  \
# 0  [prostate gland]  [reproductive system]  prostate gland         []
# 1  [prostate gland]  [reproductive system]  prostate gland         []
#
#     developmental_slims                summary                    dataset  \
# 0  [endoderm, mesoderm]  male adult (37 years)  /experiments/ENCSR153NDQ/
# 1  [endoderm, mesoderm]  male adult (54 years)  /experiments/ENCSR748RBT/
#
#               assay
# 0  Histone ChIP-seq
# 1  Histone ChIP-seq
# Enter the indices of rows to use :  0 1
#                   file                    dataset  project  \
# 0  /files/ENCFF834IDA/  /experiments/ENCSR153NDQ/  ENCODE4
# 1  /files/ENCFF937OWO/  /experiments/ENCSR153NDQ/  ENCODE4
# 2  /files/ENCFF143VBO/  /experiments/ENCSR153NDQ/  ENCODE4
# 3  /files/ENCFF514DXI/  /experiments/ENCSR748RBT/  ENCODE4
# 4  /files/ENCFF300OWT/  /experiments/ENCSR748RBT/  ENCODE4
# 5  /files/ENCFF194LKT/  /experiments/ENCSR748RBT/  ENCODE4
#
#   biological_replicates     output_type   target cell_slims  \
# 0                   [1]  signal p-value  H3K4me3         []
# 1                [1, 2]  signal p-value  H3K4me3         []
# 2                   [2]  signal p-value  H3K4me3         []
# 3                   [2]  signal p-value  H3K4me3         []
# 4                [1, 2]  signal p-value  H3K4me3         []
# 5                   [1]  signal p-value  H3K4me3         []
#
#     developmental_slims                summary       organ_slims  \
# 0  [endoderm, mesoderm]  male adult (37 years)  [prostate gland]
# 1  [endoderm, mesoderm]  male adult (37 years)  [prostate gland]
# 2  [endoderm, mesoderm]  male adult (37 years)  [prostate gland]
# 3  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
# 4  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
# 5  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
#
#             system_slims       term_name  \
# 0  [reproductive system]  prostate gland
# 1  [reproductive system]  prostate gland
# 2  [reproductive system]  prostate gland
# 3  [reproductive system]  prostate gland
# 4  [reproductive system]  prostate gland
# 5  [reproductive system]  prostate gland
#
#                                       cloud_metadata
# 0  https://encode-public.s3.amazonaws.com/2020/09...
# 1  https://encode-public.s3.amazonaws.com/2020/09...
# 2  https://encode-public.s3.amazonaws.com/2020/09...
# 3  https://encode-public.s3.amazonaws.com/2020/09...
# 4  https://encode-public.s3.amazonaws.com/2020/09...
# 5  https://encode-public.s3.amazonaws.com/2020/09...
# Enter the indices of rows to use :  1 4
# https://www.encodeproject.org/search/?type=Experiment&status=released&assay_title=TF+ChIP-seq&biosample_ontology.classification=tissue&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens&replicates.library.biosample.perturbed=false&biosample_ontology.term_name=prostate+gland&award.project=ENCODE&target.label=CTCF&frame=embedded&format=json
#         organ_slims           system_slims       term_name cell_slims  \
# 0  [prostate gland]  [reproductive system]  prostate gland         []
# 1  [prostate gland]  [reproductive system]  prostate gland         []
# 2  [prostate gland]  [reproductive system]  prostate gland         []
# 3  [prostate gland]  [reproductive system]  prostate gland         []
#
#     developmental_slims                summary                    dataset  \
# 0  [endoderm, mesoderm]  male adult (37 years)  /experiments/ENCSR946MNG/
# 1  [endoderm, mesoderm]  male adult (54 years)  /experiments/ENCSR230ORT/
# 2  [mesoderm, endoderm]  male adult (37 years)  /experiments/ENCSR720USO/
# 3  [mesoderm, endoderm]  male adult (54 years)  /experiments/ENCSR829HTO/
#
#          assay
# 0  TF ChIP-seq
# 1  TF ChIP-seq
# 2  TF ChIP-seq
# 3  TF ChIP-seq
# Enter the indices of rows to use :  0 1 2 3
#                   file                    dataset  project  \
# 0  /files/ENCFF563NCU/  /experiments/ENCSR230ORT/  ENCODE4
# 1  /files/ENCFF900BDC/  /experiments/ENCSR230ORT/  ENCODE4
# 2  /files/ENCFF412WWE/  /experiments/ENCSR230ORT/  ENCODE4
# 3  /files/ENCFF400NQB/  /experiments/ENCSR230ORT/  ENCODE4
# 4  /files/ENCFF351NKT/  /experiments/ENCSR720USO/  ENCODE4
# 5  /files/ENCFF771ZYH/  /experiments/ENCSR829HTO/  ENCODE4
# 6  /files/ENCFF703KDQ/  /experiments/ENCSR946MNG/  ENCODE4
#
#   biological_replicates                         output_type target cell_slims  \
# 0                   [1]               IDR thresholded peaks   CTCF         []
# 1                   [2]               IDR thresholded peaks   CTCF         []
# 2                [1, 2]  conservative IDR thresholded peaks   CTCF         []
# 3                [1, 2]               IDR thresholded peaks   CTCF         []
# 4                   [1]               IDR thresholded peaks   CTCF         []
# 5                   [1]               IDR thresholded peaks   CTCF         []
# 6                   [1]               IDR thresholded peaks   CTCF         []
#
#     developmental_slims                summary       organ_slims  \
# 0  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
# 1  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
# 2  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
# 3  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
# 4  [mesoderm, endoderm]  male adult (37 years)  [prostate gland]
# 5  [mesoderm, endoderm]  male adult (54 years)  [prostate gland]
# 6  [endoderm, mesoderm]  male adult (37 years)  [prostate gland]
#
#             system_slims       term_name  \
# 0  [reproductive system]  prostate gland
# 1  [reproductive system]  prostate gland
# 2  [reproductive system]  prostate gland
# 3  [reproductive system]  prostate gland
# 4  [reproductive system]  prostate gland
# 5  [reproductive system]  prostate gland
# 6  [reproductive system]  prostate gland
#
#                                       cloud_metadata
# 0  https://encode-public.s3.amazonaws.com/2020/09...
# 1  https://encode-public.s3.amazonaws.com/2020/09...
# 2  https://encode-public.s3.amazonaws.com/2020/09...
# 3  https://encode-public.s3.amazonaws.com/2020/09...
# 4  https://encode-public.s3.amazonaws.com/2020/09...
# 5  https://encode-public.s3.amazonaws.com/2020/09...
# 6  https://encode-public.s3.amazonaws.com/2020/09...
# Enter the indices of rows to use :  3 4 5 6
# https://www.encodeproject.org/search/?type=Experiment&status=released&assay_title=total+RNA-seq&assay_title=polyA+plus+RNA-seq&biosample_ontology.classification=tissue&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens&replicates.library.biosample.perturbed=false&biosample_ontology.term_name=prostate+gland&award.project=ENCODE&frame=embedded&format=json
#         organ_slims           system_slims       term_name cell_slims  \
# 0  [prostate gland]  [reproductive system]  prostate gland         []
# 1  [prostate gland]  [reproductive system]  prostate gland         []
#
#     developmental_slims                summary                    dataset  \
# 0  [endoderm, mesoderm]  male adult (54 years)  /experiments/ENCSR701TST/
# 1  [endoderm, mesoderm]  male adult (37 years)  /experiments/ENCSR495HDM/
#
#            assay
# 0  total RNA-seq
# 1  total RNA-seq
# Enter the indices of rows to use :  0 1
#                   file                    dataset  project  \
# 0  /files/ENCFF042VIA/  /experiments/ENCSR495HDM/  ENCODE4
# 1  /files/ENCFF485OGN/  /experiments/ENCSR701TST/  ENCODE4
#
#   biological_replicates           output_type cell_slims  \
# 0                   [1]  gene quantifications         []
# 1                   [1]  gene quantifications         []
#
#     developmental_slims                summary       organ_slims  \
# 0  [endoderm, mesoderm]  male adult (37 years)  [prostate gland]
# 1  [endoderm, mesoderm]  male adult (54 years)  [prostate gland]
#
#             system_slims       term_name  \
# 0  [reproductive system]  prostate gland
# 1  [reproductive system]  prostate gland
#
#                                       cloud_metadata
# 0  https://encode-public.s3.amazonaws.com/2020/07...
# 1  https://encode-public.s3.amazonaws.com/2020/07...
# Enter the indices of rows to use :  0 1
# defaultdict(list,
#             {'H3K4me3': ['https://encode-public.s3.amazonaws.com/2020/09/24/4d3da9ba-7b18-4b70-80d1-5e1cf1e40464/ENCFF937OWO.bigWig',
#               'https://encode-public.s3.amazonaws.com/2020/09/22/a57dc2a8-bf4e-4d5f-93a0-f436c1b7923d/ENCFF300OWT.bigWig'],
#              'CTCF': ['https://encode-public.s3.amazonaws.com/2020/09/24/1e953256-aa80-4397-803f-a298c2bfc390/ENCFF400NQB.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/01/81710556-6615-4cc2-b3ef-cd40df5f9421/ENCFF351NKT.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/01/392b4a9e-c4fe-4c36-abde-c7f20d21f14d/ENCFF771ZYH.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/24/e56c35ea-7d69-42fb-9903-860a434a4b72/ENCFF703KDQ.bed.gz'],
#              'transcription': ['https://encode-public.s3.amazonaws.com/2020/07/14/3f67db5f-ff26-4ce7-993b-893b64b9af80/ENCFF042VIA.tsv',
#               'https://encode-public.s3.amazonaws.com/2020/07/14/d95a027d-ca9b-4f55-b66a-e6a54f92335e/ENCFF485OGN.tsv']})

# %%
results
# Out:
# defaultdict(list,
#             {'H3K4me3': ['https://encode-public.s3.amazonaws.com/2020/09/24/4d3da9ba-7b18-4b70-80d1-5e1cf1e40464/ENCFF937OWO.bigWig',
#               'https://encode-public.s3.amazonaws.com/2020/09/22/a57dc2a8-bf4e-4d5f-93a0-f436c1b7923d/ENCFF300OWT.bigWig'],
#              'CTCF': ['https://encode-public.s3.amazonaws.com/2020/09/24/1e953256-aa80-4397-803f-a298c2bfc390/ENCFF400NQB.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/01/81710556-6615-4cc2-b3ef-cd40df5f9421/ENCFF351NKT.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/01/392b4a9e-c4fe-4c36-abde-c7f20d21f14d/ENCFF771ZYH.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/24/e56c35ea-7d69-42fb-9903-860a434a4b72/ENCFF703KDQ.bed.gz'],
#              'transcription': ['https://encode-public.s3.amazonaws.com/2020/07/14/3f67db5f-ff26-4ce7-993b-893b64b9af80/ENCFF042VIA.tsv',
#               'https://encode-public.s3.amazonaws.com/2020/07/14/d95a027d-ca9b-4f55-b66a-e6a54f92335e/ENCFF485OGN.tsv']})

# %%
# find cell line sample if tissue sample is not available for the feature
c2 = encode.FeatureConfig('prostate',  False, True, "transcription", ) # change 3rd arg to True 
results2 = c2.parse_url(rfa='ENCODE4')
# Out:
# https://www.encodeproject.org/search/?type=Experiment&status=released&assay_title=total+RNA-seq&assay_title=polyA+plus+RNA-seq&biosample_ontology.classification=cell+line&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens&replicates.library.biosample.perturbed=false&searchTerm=prostate&award.project=ENCODE&frame=embedded&format=json
#         organ_slims           system_slims term_name     cell_slims  \
# 0  [prostate gland]  [reproductive system]      PC-3  [cancer cell]
# 1  [prostate gland]  [reproductive system]      PC-3  [cancer cell]
#
#     developmental_slims summary                    dataset          assay
# 0  [mesoderm, endoderm]          /experiments/ENCSR648KDM/  total RNA-seq
# 1  [mesoderm, endoderm]          /experiments/ENCSR420NLC/  total RNA-seq
# Enter the indices of rows to use :  0 1
#                   file                    dataset  project  \
# 0  /files/ENCFF882EWJ/  /experiments/ENCSR420NLC/  ENCODE4
# 1  /files/ENCFF970ZLV/  /experiments/ENCSR420NLC/  ENCODE4
# 2  /files/ENCFF617JTM/  /experiments/ENCSR648KDM/  ENCODE4
#
#   biological_replicates           output_type     cell_slims  \
# 0                   [2]  gene quantifications  [cancer cell]
# 1                   [1]  gene quantifications  [cancer cell]
# 2                   [1]  gene quantifications  [cancer cell]
#
#     developmental_slims summary       organ_slims           system_slims  \
# 0  [mesoderm, endoderm]          [prostate gland]  [reproductive system]
# 1  [mesoderm, endoderm]          [prostate gland]  [reproductive system]
# 2  [mesoderm, endoderm]          [prostate gland]  [reproductive system]
#
#   term_name                                     cloud_metadata
# 0      PC-3  https://encode-public.s3.amazonaws.com/2021/06...
# 1      PC-3  https://encode-public.s3.amazonaws.com/2021/06...
# 2      PC-3  https://encode-public.s3.amazonaws.com/2020/10...
# Enter the indices of rows to use :  0 1 2

# %%
results2
# Out:
# defaultdict(list,
#             {'transcription': ['https://encode-public.s3.amazonaws.com/2021/06/01/4c7dfb36-4825-4a92-808b-d963cfa388bc/ENCFF882EWJ.tsv',
#               'https://encode-public.s3.amazonaws.com/2021/06/01/639c03fd-3fc5-442d-a5d4-2badb8d1091e/ENCFF970ZLV.tsv',
#               'https://encode-public.s3.amazonaws.com/2020/10/30/ae4ec0f6-6070-4977-93b8-befc070764b9/ENCFF617JTM.tsv']})

# %%
# if you are not sure of exact sample ontology available in ENCODE, change 2nd arg to False
c3 = encode.FeatureConfig('breast',  False, False, "H3K4me3", "CTCF", )

# %%
results3 = c3.parse_url()
# Out:
# https://www.encodeproject.org/search/?type=Experiment&status=released&assay_title=Histone+ChIP-seq&biosample_ontology.classification=tissue&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens&replicates.library.biosample.perturbed=false&searchTerm=breast&award.project=ENCODE&target.label=H3K4me3&frame=embedded&format=json
#             organ_slims system_slims          term_name cell_slims  \
# 0  [breast, epithelium]           []  breast epithelium         []
# 1  [breast, epithelium]           []  breast epithelium         []
# 2  [epithelium, breast]           []  breast epithelium         []
#
#   developmental_slims                  summary                    dataset  \
# 0                  []  female adult (53 years)  /experiments/ENCSR416AUW/
# 1                  []    male adult (37 years)  /experiments/ENCSR224STY/
# 2                  []  female adult (51 years)  /experiments/ENCSR568QQU/
#
#               assay
# 0  Histone ChIP-seq
# 1  Histone ChIP-seq
# 2  Histone ChIP-seq
# Enter the indices of rows to use :  0 2
#                   file                    dataset  project  \
# 0  /files/ENCFF449LNR/  /experiments/ENCSR416AUW/  ENCODE4
# 1  /files/ENCFF534QEF/  /experiments/ENCSR416AUW/  ENCODE4
# 2  /files/ENCFF200LAB/  /experiments/ENCSR416AUW/  ENCODE4
# 3  /files/ENCFF403VNT/  /experiments/ENCSR568QQU/  ENCODE4
#
#   biological_replicates     output_type   target cell_slims  \
# 0                [1, 2]  signal p-value  H3K4me3         []
# 1                   [1]  signal p-value  H3K4me3         []
# 2                   [2]  signal p-value  H3K4me3         []
# 3                   [1]  signal p-value  H3K4me3         []
#
#   developmental_slims                  summary           organ_slims  \
# 0                  []  female adult (53 years)  [breast, epithelium]
# 1                  []  female adult (53 years)  [breast, epithelium]
# 2                  []  female adult (53 years)  [breast, epithelium]
# 3                  []  female adult (51 years)  [epithelium, breast]
#
#   system_slims          term_name  \
# 0           []  breast epithelium
# 1           []  breast epithelium
# 2           []  breast epithelium
# 3           []  breast epithelium
#
#                                       cloud_metadata
# 0  https://encode-public.s3.amazonaws.com/2020/10...
# 1  https://encode-public.s3.amazonaws.com/2020/10...
# 2  https://encode-public.s3.amazonaws.com/2020/10...
# 3  https://encode-public.s3.amazonaws.com/2020/09...
# Enter the indices of rows to use :  0 2 3
# https://www.encodeproject.org/search/?type=Experiment&status=released&assay_title=TF+ChIP-seq&biosample_ontology.classification=tissue&replicates.library.biosample.donor.organism.scientific_name=Homo+sapiens&replicates.library.biosample.perturbed=false&searchTerm=breast&award.project=ENCODE&target.label=CTCF&frame=embedded&format=json
#             organ_slims system_slims          term_name cell_slims  \
# 0  [breast, epithelium]           []  breast epithelium         []
# 1  [breast, epithelium]           []  breast epithelium         []
# 2  [epithelium, breast]           []  breast epithelium         []
#
#   developmental_slims                  summary                    dataset  \
# 0                  []    male adult (54 years)  /experiments/ENCSR697YIN/
# 1                  []  female adult (53 years)  /experiments/ENCSR304XUZ/
# 2                  []  female adult (51 years)  /experiments/ENCSR661NXJ/
#
#          assay
# 0  TF ChIP-seq
# 1  TF ChIP-seq
# 2  TF ChIP-seq
# Enter the indices of rows to use :  1 2
#                   file                    dataset  project  \
# 0  /files/ENCFF910ACN/  /experiments/ENCSR304XUZ/  ENCODE4
# 1  /files/ENCFF530ARF/  /experiments/ENCSR661NXJ/  ENCODE4
#
#   biological_replicates            output_type target cell_slims  \
# 0                   [1]  IDR thresholded peaks   CTCF         []
# 1                   [1]  IDR thresholded peaks   CTCF         []
#
#   developmental_slims                  summary           organ_slims  \
# 0                  []  female adult (53 years)  [breast, epithelium]
# 1                  []  female adult (51 years)  [epithelium, breast]
#
#   system_slims          term_name  \
# 0           []  breast epithelium
# 1           []  breast epithelium
#
#                                       cloud_metadata
# 0  https://encode-public.s3.amazonaws.com/2020/10...
# 1  https://encode-public.s3.amazonaws.com/2020/09...
# Enter the indices of rows to use :  0 1

# %%
results3
# Out:
# defaultdict(list,
#             {'H3K4me3': ['https://encode-public.s3.amazonaws.com/2020/10/10/a190f445-dec2-4e07-955e-da1756f10bc4/ENCFF449LNR.bigWig',
#               'https://encode-public.s3.amazonaws.com/2020/10/10/57b16f05-6dad-42b3-be58-aeba328ca24b/ENCFF200LAB.bigWig',
#               'https://encode-public.s3.amazonaws.com/2020/09/23/64fc5b6a-f571-46e1-863a-84a3d73ab1fb/ENCFF403VNT.bigWig'],
#              'CTCF': ['https://encode-public.s3.amazonaws.com/2020/10/10/ceaa3a29-86bb-4e42-ace8-a79bf821398f/ENCFF910ACN.bed.gz',
#               'https://encode-public.s3.amazonaws.com/2020/09/01/29a4d2b3-6426-4c8b-9859-15df343fc1e8/ENCFF530ARF.bed.gz']})
